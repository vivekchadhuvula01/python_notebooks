# %%
'''
* Pandas is a python package providing fast, flexible, and expressive data structures
designed to make working with 'relational' or 'labled' data both easy and intuitive.
* The name 'Pandas ' has a reference to both 'Panel Data ' & 'Python Data Analysis' and
was created by Wes McKinney in 2008.
* Pandas is used to clean, analyse & explore the data.
* Handlilng of data becomes easy with the help of Pandas.
* Intelligent labeled-based slicing, fancy indexing and subsetting of large data sets.
* Flexible reshaping and pivoting of data sets.

'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
'''
Series in Pandas:
Pandas Series is a One_Dimensional labeled array capable of holding data of any type.
Pandas Series is nothing but a column in an excel sheet.

DataFrames in Pandas:
Pandas DataFrame is Two_Dimensional size_mutable heterozenous tabular data structure with labeled axes(rows and columns).
data is aligned in a tabular format rows and columns.
pandas Dataframe consist of 3 principle components, the data, rows, and columns.
'''
# Out:
# '\nSeries in Pandas:\nPandas Series is a One_Dimensional labeled array capable of holding data of any type.\nPandas Series is nothing but a column in an excel sheet.\n\nDataFrames in Pandas:\nPandas DataFrame is Two_Dimensional size_mutable heterozenous tabular data structure with labeled axes(rows and columns).\ndata is aligned in a tabular format rows and columns.\npandas Dataframe consist of 3 principle components, the data, rows, and columns.\n'

# %%
data = pd.DataFrame(
    {
        'id':[1,2,3,4,5],
        'name':['ram','bim','liya','roma','kin'],
        'age':[18,20,19,20,18]
    })
(data)
# Out:
#    id  name  age
# 0   1   ram   18
# 1   2   bim   20
# 2   3  liya   19
# 3   4  roma   20
# 4   5   kin   18

# %%
cards = pd.read_csv("fin_cards.csv")
cards
# Out:
#         id  client_id  card_brand        card_type       card_number  expires
# 0     4524        825        Visa            Debit  4344676511950444  12/2022  \
# 1     2731        825        Visa            Debit  4956965974959986  12/2020
# 2     3701        825        Visa            Debit  4582313478255491  02/2024
# 3       42        825        Visa           Credit  4879494103069057  08/2024
# 4     4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
# ...    ...        ...         ...              ...               ...      ...
# 6141  5361        185        Amex           Credit   300609782832003  01/2024
# 6142  2711        185        Visa           Credit  4718517475996018  01/2021
# 6143  1305       1007  Mastercard           Credit  5929512204765914  08/2020
# 6144   743       1110  Mastercard            Debit  5589768928167462  01/2020
# 6145  3199       1110        Visa           Credit  4994011318343994  12/2020
#
# ...

# %%
cards.head(20)
# Out:
#       id  client_id  card_brand        card_type       card_number  expires
# 0   4524        825        Visa            Debit  4344676511950444  12/2022  \
# 1   2731        825        Visa            Debit  4956965974959986  12/2020
# 2   3701        825        Visa            Debit  4582313478255491  02/2024
# 3     42        825        Visa           Credit  4879494103069057  08/2024
# 4   4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
# 5   4537       1746        Visa           Credit  4404898874682993  09/2003
# 6   1278       1746        Visa            Debit  4001482973848631  07/2022
# 7   3687       1746  Mastercard            Debit  5627220683410948  06/2022
# 8   3465       1746  Mastercard  Debit (Prepaid)  5711382187309326  11/2020
# 9   3754       1746  Mastercard  Debit (Prepaid)  5766121508358701  02/2023
# 10  5144       1718  Mastercard            Debit  5495199163052054  03/2022
# ...

# %%
# cards.groupby('card_brand').sum()

# %%
cards.describe()
# Out:
#                 id    client_id   card_number          cvv  num_cards_issued
# count  6146.000000  6146.000000  6.146000e+03  6146.000000       6146.000000  \
# mean   3072.500000   994.939636  4.820426e+15   506.220794          1.503091
# std    1774.341709   578.614626  1.328582e+15   289.431123          0.519191
# min       0.000000     0.000000  3.001055e+14     0.000000          1.000000
# 25%    1536.250000   492.250000  4.486365e+15   257.000000          1.000000
# 50%    3072.500000   992.000000  5.108957e+15   516.500000          1.000000
# 75%    4608.750000  1495.000000  5.585237e+15   756.000000          2.000000
# max    6145.000000  1999.000000  6.997197e+15   999.000000          3.000000
#
#        year_pin_last_changed
# count            6146.000000
# mean             2013.436707
# std                 4.270699
# min              2002.000000
# 25%              2010.000000
# 50%              2013.000000
# 75%              2017.000000
# max              2020.000000

# %%
cards.isnull().sum()  #counting null values
# Out:
# id                       0
# client_id                0
# card_brand               0
# card_type                0
# card_number              0
# expires                  0
# cvv                      0
# has_chip                 0
# num_cards_issued         0
# credit_limit             0
# acct_open_date           0
# year_pin_last_changed    0
# card_on_dark_web         0
# dtype: int64

# %%
# handling duplicate values
cards['card_type'].duplicated().sum()
# Out:
# 6143

# %%
df= pd.DataFrame(np.random.randn(1000,4), columns=['a','b','c','d'])
df = df.cumsum()
plt.figure()
df.plot()
plt.legend(loc='best')

# %%
fig, ax = plt.subplots()             # Create a figure containing a single Axes.
ax.scatter([2, 20, 32, 48], [1.5, 4.2, 2.8, 3.33])   # Plot some data on the Axes.

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
data = pd.DataFrame({'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)})
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')
